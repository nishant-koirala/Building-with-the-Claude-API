# %%
import os
from dotenv import load_dotenv
from anthropic import Anthropic

# Load your .env file
load_dotenv()

# Configuration Constants
OPENROUTER_API_KEY = os.getenv("OPENROUTER_API_KEY")
BASE_URL = "https://openrouter.ai/api" # The "Secret Sauce" for the Anthropic SDK
MODEL_NAME = "google/gemini-2.0-flash-001" # Fast and cheap for development

# Initialize the client once
client = Anthropic(
    base_url=BASE_URL,
    api_key=OPENROUTER_API_KEY
)

# %%
messages = []

def chat(messages):
    message = client.messages.create(
        model=MODEL_NAME,
        max_tokens=10,
        messages=messages,
    )
    return message.content[0].text

while True:
    user_input = input("You: ")
    if user_input.lower() == "exit":
        print("Goodbye!")
        break

    # Add user message to the message list
    messages.append({"role": "user", "content": user_input})

    # Get response from model
    response = chat(messages)
    

    # Add assistant response to history
    messages.append({"role": "assistant", "content": response})

    #print generated message
    print("User:", user_input)
    print("Generated message:", response)
    print("-" * 50)
# Out:
# User: hi
# Generated message: Hi there! How can I help you today?
# --------------------------------------------------
# Goodbye!
